# %%
import pip
from subprocess import call

for dist in pip.get_installed_distributions():
    call("pip install --upgrade " + dist.project_name, shell=True)

# %%
import stl
import numpy as np
from mpl_toolkits import mplot3d
from matplotlib import pyplot
from sklearn.cluster import KMeans
import collections
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xa but this version of numpy is 0x9
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-ae8663a068e0> in <module>()
#       1 import stl
#       2 import numpy as np
# ----> 3 from mpl_toolkits import mplot3d
#       4 from matplotlib import pyplot
#       5 from sklearn.cluster import KMeans
#
# C:\Users\Louis\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\__init__.py in <module>()
#       4 from matplotlib.externals import six
#       5
# ----> 6 from .axes3d import Axes3D
#
# C:\Users\Louis\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in <module>()
#      20 from operator import itemgetter
#      21
# ---> 22 import matplotlib.axes as maxes
#      23 from matplotlib.axes import Axes, rcParams
#      24 from matplotlib import cbook
#
# C:\Users\Louis\Anaconda2\lib\site-packages\matplotlib\axes\__init__.py in <module>()
#       2                         unicode_literals)
#       3
# ----> 4 from ._subplots import *
#       5 from ._axes import *
#
# C:\Users\Louis\Anaconda2\lib\site-packages\matplotlib\axes\_subplots.py in <module>()
#       5 from matplotlib.externals.six.moves import map
#       6
# ----> 7 from matplotlib.gridspec import GridSpec, SubplotSpec
#       8 from matplotlib import docstring
#       9 import matplotlib.artist as martist
#
# C:\Users\Louis\Anaconda2\lib\site-packages\matplotlib\gridspec.py in <module>()
#      24 rcParams = matplotlib.rcParams
#      25
# ---> 26 import matplotlib.transforms as mtransforms
#      27
#      28 import numpy as np
#
# C:\Users\Louis\Anaconda2\lib\site-packages\matplotlib\transforms.py in <module>()
#      37 import numpy as np
#      38 from numpy import ma
# ---> 39 from matplotlib._path import (affine_transform, count_bboxes_overlapping_bbox,
#      40     update_path_extents)
#      41 from numpy.linalg import inv
#
# ImportError: numpy.core.multiarray failed to import

# %%
upper_mesh = stl.mesh.Mesh.from_file('../Models/upper.stl')

# %%
kmeans = KMeans(n_clusters=7, random_state=0).fit(upper_mesh.normals)

# %%
# Create a new plot
figure = pyplot.figure()
ax = figure.add_subplot(111, projection="3d")
N = upper_mesh.normals.T

ax.scatter(N[0], N[1], N[2], c = 'r')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Show the plot to the screen
pyplot.show()

# %%
count = collections.defaultdict(int)
for i in kmeans.labels_:
    count[i] += 1
print(count)
# Out:
# defaultdict(<class 'int'>, {0: 17288, 1: 26763, 2: 151130, 3: 25345, 4: 27049, 5: 35216, 6: 25432})

# %%
# Out:
# defaultdict(<class 'int'>, {0: 152736, 1: 42371, 2: 28028, 3: 38684, 4: 18875, 5: 27529})

# %%
test = np.array([[0, 1], [2, 3], [4, 5]])
print(test)
#M[0][1]
print(test[0][1])
#COL 0
print(test[:,0])
#COL 1
print(test[:, 1])
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]
# 1
# [0 2 4]
# [1 3 5]
